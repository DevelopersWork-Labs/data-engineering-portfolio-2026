# %% [markdown]
# ## 1️⃣ Install & import

# %%
# %pip install pinecone
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import pinecone

# %% [markdown]
# ## 2️⃣ Initialize client

# %%
# %env PINECONE_API_KEY=<PINECONE_API_KEY>

# %%
import os
from pinecone import Pinecone

PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
assert PINECONE_API_KEY is not None

pc = Pinecone(api_key=PINECONE_API_KEY)

# %% [markdown]
# ## ✅ Step 3: Create a Demo Index (Hello Vector)

# %%
from pinecone import ServerlessSpec

index_name = "day7-hello-vector"
if index_name not in pc.list_indexes():
  pc.create_index(
    name=index_name,
    dimension=3,
    metric="cosine",
    spec=ServerlessSpec(
      cloud="aws",
      region="us-east-1"
    )
)

# %% [markdown]
# ## ✅ Step 4: Upsert a Dummy Vector

# %%
index = pc.Index(index_name)

index.upsert([
    ("vec1", [0.1, 0.2, 0.3], {"text": "hello vector db"})
])
# Out:
# UpsertResponse(upserted_count=1, _response_info={'raw_headers': {'date': 'Fri, 02 Jan 2026 13:51:57 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '2', 'x-pinecone-request-logical-size': '43', 'x-pinecone-request-latency-ms': '156', 'x-pinecone-request-id': '1042217542602008105', 'x-envoy-upstream-service-time': '157', 'x-pinecone-response-duration-ms': '158', 'grpc-status': '0', 'server': 'envoy'}})

# %% [markdown]
# ## ✅ Step 5: Query It Back

# %%
index.query(
    vector=[0.1, 0.2, 0.29],
    top_k=1,
    include_metadata=True
)
# Out:
# QueryResponse(matches=[{'id': 'vec1',
#  'metadata': {'text': 'hello vector db'},
#  'score': 0.999065936,
#  'values': []}], namespace='', usage={'read_units': 1}, _response_info={'raw_headers': {'date': 'Fri, 02 Jan 2026 13:51:51 GMT', 'content-type': 'application/json', 'content-length': '149', 'connection': 'keep-alive', 'x-pinecone-max-indexed-lsn': '1', 'x-pinecone-request-latency-ms': '37', 'x-pinecone-request-id': '3434289437236908764', 'x-envoy-upstream-service-time': '38', 'x-pinecone-response-duration-ms': '39', 'grpc-status': '0', 'server': 'envoy'}})
